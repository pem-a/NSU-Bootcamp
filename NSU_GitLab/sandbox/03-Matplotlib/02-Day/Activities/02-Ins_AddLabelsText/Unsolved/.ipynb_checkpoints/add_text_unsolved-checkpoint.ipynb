# %% [markdown]
# ### Add Text in The Plot - Unsolved Version

# %%
# %matplotlib notebook

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Add simple text
plt.text(1,2,"text")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Add text w/ font sixe and color

# %%
# Add text right alignment
