# %% [markdown]
# ### Pyber Ride Count by City Type - Solved Version

# %%
# %matplotlib notebook

# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the dataset into a pandas df and make sure to set index to column 0
ride_count = pd.read_csv('../Resources/pyber_ridercount.csv', index_col=0)
ride_count
# Out:
#                       Rural  Urban  Suburban
# Unnamed: 0
# Port Angela              67    137        52
# Barajasview              67     47        43
# West Christopherberg     26     64        55
# New Jacobville           35     50        28
# Port David               35     44        30
# Valentineton             21     20        55
# Carriemouth              25     23        34
# Williamsstad             24      8        38
# Royland                  61      4         4
# Karenberg                34     17        13

# %%
# Create a figure and axes object 
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
# Add bars for "Urban" with the label "Urban"
ax.bar(ride_count.index, ride_count["Urban"], label="Urban")
# Out:
# <BarContainer object of 10 artists>

# %%
# Stack bars for "Suburban" on top with label "Suburban"
ax.bar(ride_count.index, ride_count["Suburban"], bottom=ride_count["Urban"], label="Suburban")
# Out:
# <BarContainer object of 10 artists>

# %%
# Stack bars for "Rural" on top of that with label "Rural"
ax.bar(ride_count.index, ride_count["Rural"], bottom=ride_count["Urban"] + ride_count["Suburban"], label='Rural')
# Out:
# <BarContainer object of 10 artists>

# %%
# Rotataing the tick labels vertically
ax.set_xticklabels(ride_count.index, rotation=90)
# Out:
# <ipython-input-19-06644ad2c8c5>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ride_count.index, rotation=90)
# [Text(0, 0, 'Port Angela'),
#  Text(1, 0, 'Barajasview'),
#  Text(2, 0, 'West Christopherberg'),
#  Text(3, 0, 'New Jacobville'),
#  Text(4, 0, 'Port David'),
#  Text(5, 0, 'Valentineton'),
#  Text(6, 0, 'Carriemouth'),
#  Text(7, 0, 'Williamsstad'),
#  Text(8, 0, 'Royland'),
#  Text(9, 0, 'Karenberg')]

# %%
# Setting the y label 
ax.set_ylabel('Number of Rides')
# Out:
# Text(26.937498650617066, 0.5, 'Number of Rides')

# %%
# Display the legend
ax.legend()

# %%
# Use plt.tight_layout() to improve the spacing in the figure
plt.tight_layout()
plt.show()
