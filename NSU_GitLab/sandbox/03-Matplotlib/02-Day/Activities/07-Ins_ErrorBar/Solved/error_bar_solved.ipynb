# %%
# %matplotlib notebook

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset into a pandas df 
ride_count = pd.read_csv('../Resources/pyber_ridercount.csv')
ride_count
# Out:
#              Unnamed: 0  Rural  Urban  Suburban
# 0           Port Angela     67    137        52
# 1           Barajasview     67     47        43
# 2  West Christopherberg     26     64        55
# 3        New Jacobville     35     50        28
# 4            Port David     35     44        30
# 5          Valentineton     21     20        55
# 6           Carriemouth     25     23        34
# 7          Williamsstad     24      8        38
# 8               Royland     61      4         4
# 9             Karenberg     34     17        13

# %%
# Create a figure and axes object 
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
# Add a bar for the rural column mean/std
ax.bar('Rural', 
       ride_count['Rural'].mean(), 
       yerr=ride_count['Rural'].std(), 
       align='center',
       alpha=0.5,
       capsize=10)
# Out:
# <BarContainer object of 1 artists>

# %%
# Add a bar for the urban column mean/std
ax.bar('Urban', 
       ride_count['Urban'].mean(), 
       yerr=ride_count['Urban'].std(), 
       align='center',
       alpha=0.5,
       capsize=10)
# Out:
# <BarContainer object of 1 artists>

# %%
# Add a bar for the suburban column mean/std
ax.bar('Suburban', 
       ride_count['Suburban'].mean(), 
       yerr=ride_count['Suburban'].std(), 
       align='center',
       alpha=0.5,
       capsize=10)
# Out:
# <BarContainer object of 1 artists>

# %%
# Set the y label and add grid for y axis
ax.set_ylabel('Ride Average')
ax.yaxis.grid(True)

# %%
plt.show()
