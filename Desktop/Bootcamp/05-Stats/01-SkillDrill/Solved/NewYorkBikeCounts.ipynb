# %%
# Dependencies
import pandas as pd
import plotly.express as plt
import os
import statsmodels.api as sm

# %%
bikecounts_file = os.path.join('../','Resources', 'bikecounts.csv')
bikecounts_df = pd.read_csv(bikecounts_file)
bikecounts_df['Day'] = pd.to_datetime(bikecounts_df['Day'])
bikecounts_df.head()
# Out:
#    Unnamed: 0        Date        Day  High Temp (°F)  Low Temp (°F)  \
# 0           0  2016-04-01 2016-04-01            78.1           66.0
# 1           1  2016-04-02 2016-04-02            55.0           48.9
# 2           2  2016-04-03 2016-04-03            39.9           34.0
# 3           3  2016-04-04 2016-04-04            44.1           33.1
# 4           4  2016-04-05 2016-04-05            42.1           26.1
#
#   Precipitation  Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  \
# 0          0.01           1704.0              3126               4115.0
# 1          0.15            827.0              1646               2565.0
# 2          0.09            526.0              1232               1695.0
# 3      0.47 (S)            521.0              1067               1440.0
# 4             0           1416.0              2617               3081.0
#
#    Queensboro Bridge  Total
# 0             2552.0  11497
# 1             1884.0   6922
# 2             1306.0   4759
# 3             1307.0   4335
# 4             2357.0   9471

# %%
bikecounts_df.rename(columns={'High Temp (°F)': 'High Temp', 'Low Temp (°F)':'Low Temp'},inplace = True)
bikecounts_df.head()
# Out:
#    Unnamed: 0        Date        Day  High Temp  Low Temp Precipitation  \
# 0           0  2016-04-01 2016-04-01       78.1      66.0          0.01
# 1           1  2016-04-02 2016-04-02       55.0      48.9          0.15
# 2           2  2016-04-03 2016-04-03       39.9      34.0          0.09
# 3           3  2016-04-04 2016-04-04       44.1      33.1      0.47 (S)
# 4           4  2016-04-05 2016-04-05       42.1      26.1             0
#
#    Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  Queensboro Bridge  \
# 0           1704.0              3126               4115.0             2552.0
# 1            827.0              1646               2565.0             1884.0
# 2            526.0              1232               1695.0             1306.0
# 3            521.0              1067               1440.0             1307.0
# 4           1416.0              2617               3081.0             2357.0
#
#    Total
# 0  11497
# 1   6922
# 2   4759
# 3   4335
# 4   9471

# %%
def remove_unwanted(x):
    for unwanted_char in ['T', '(S)', ' ']:
        x=x.replace(unwanted_char, '')
    return x
bikecounts_df['Precipitation']=bikecounts_df['Precipitation'].apply(remove_unwanted)
bikecounts_df['Precipitation']=bikecounts_df['Precipitation'].replace('',0).astype('float64')
bikecounts_df.head(10)
# Out:
#    Unnamed: 0        Date        Day  High Temp  Low Temp  Precipitation  \
# 0           0  2016-04-01 2016-04-01       78.1      66.0           0.01
# 1           1  2016-04-02 2016-04-02       55.0      48.9           0.15
# 2           2  2016-04-03 2016-04-03       39.9      34.0           0.09
# 3           3  2016-04-04 2016-04-04       44.1      33.1           0.47
# 4           4  2016-04-05 2016-04-05       42.1      26.1           0.00
# 5           5  2016-04-06 2016-04-06       45.0      30.0           0.00
# 6           6  2016-04-07 2016-04-07       57.0      53.1           0.09
# 7           7  2016-04-08 2016-04-08       46.9      44.1           0.01
# 8           8  2016-04-09 2016-04-09       43.0      37.9           0.09
# 9           9  2016-04-10 2016-04-10       48.9      30.9           0.00
#
#    Brooklyn Bridge  Manhattan Bridge  Williamsburg Bridge  Queensboro Bridge  \
# 0           1704.0              3126               4115.0             2552.0
# 1            827.0              1646               2565.0             1884.0
# 2            526.0              1232               1695.0             1306.0
# 3            521.0              1067               1440.0             1307.0
# 4           1416.0              2617               3081.0             2357.0
# 5           1885.0              3329               3856.0             2849.0
# 6           1276.0              2581               3282.0             2457.0
# 7           1982.0              3455               4113.0             3194.0
# 8            504.0               997               1507.0             1502.0
# 9           1447.0              2387               3132.0             2160.0
#
#    Total
# 0  11497
# 1   6922
# 2   4759
# 3   4335
# 4   9471
# 5  11919
# 6   9596
# 7  12744
# 8   4510
# 9   9126

# %%
# Select your independent X terms, and your dependent y term. 
X = bikecounts_df[['Precipitation','High Temp']]
y = bikecounts_df['Brooklyn Bridge']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()

# %%
# Print the linear regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Brooklyn Bridge   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     28.81
# Date:                Mon, 22 Mar 2021   Prob (F-statistic):           2.01e-07
# Time:                        13:59:02   Log-Likelihood:                -232.03
# No. Observations:                  30   AIC:                             470.1
# Df Residuals:                      27   BIC:                             474.3
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -746.2092    647.158     -1.153      0.259   -2074.068     581.649
# Precipitation -3751.0121   1112.981     -3.370      0.002   -6034.660   -1467.364
# High Temp        53.0232     10.166      5.216      0.000      32.164      73.882
# ==============================================================================
# Omnibus:                        5.130   Durbin-Watson:                   1.022
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                3.621
# Skew:                          -0.812   Prob(JB):                        0.164
# Kurtosis:                       3.507   Cond. No.                         670.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
